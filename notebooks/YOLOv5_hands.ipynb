# %% [markdown]
# # Load YOLOv5 repository

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -qr yolov5/requirements.txt  # install dependencies (ignore errors)
# %cd yolov5

import torch

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import matplotlib.pyplot as plt
import shutil
import json
import numpy as np
import pandas as pd
import cv2
import time

# %% [markdown]
# # Dataset configuration

# %%
def get_info(data):

  '''
  Read int and float numbers from str line
  Input:
    - data - column as numpy array from .csv table
  Output:
    - new_data - list of lists with int and float numbers (bbox coords or keypoint coords)
  '''

  new_data = []
  for i in range(len(data)):
    example = [float(x.strip()) if '.' in x else int(x.strip()) for x in data[i][1:-1].split(',')]
    new_data.append(example)

  return new_data

# %%
def prepare_yolo_data(unique_filenames, bboxes, images_names, images_path, labels_path):

  '''
  Create textfiles for yolov5 training
  Input:
    - unique_filenames - names of unique images in dataset
    - bboxes - numpy array with coordinates of hands bboxes
    - images_names - numpy array with image filenames with hands
    - images_path - path for folder with images
    - labels_path - path for folder with textfiles
  '''

  # Loop through unique images
  for image_name in unique_filenames:
    img = cv2.imread(os.path.join(images_path, image_name))
    img_high, img_wight = img.shape[0], img.shape[1]
    img_boxes_list = []

    indices = np.where(images_names == image_name)[0]
    # Write each bbox for current image
    for ind in indices:
      bbox = bboxes[ind].copy()
      x_ind, y_ind = bbox[0:2] + bbox[2:4] // 2
      w_ind, h_ind = bbox[2:4]

      str_box = '0' + ' ' + \
                str(round(x_ind/img_wight,4))+ ' ' + \
                str(round(y_ind/img_high,4))+ ' ' + \
                str(round(w_ind/img_wight,4))+ ' ' + \
                str(round(h_ind/img_high,4))

      img_boxes_list.append(str_box)

    # Write annotation information in .txt file for current image
    file_bbx_name = image_name[:-3]
    file_bbx_name += 'txt' 
    with open(labels_path + file_bbx_name, 'w') as output:
      for row in img_boxes_list:
        if row == img_boxes_list[-1]:
          output.write(str(row))
        else:
          output.write(str(row) + '\n')

# %% [markdown]
# ## Val

# %%
# !unzip -q /content/drive/MyDrive/pose_estimation/hands_val.zip -d '/content/val_images/'

# %%
# !rm -r '/content/data/labels/valid'
# !rm -r '/content/data/images/valid'
# Make directioris like yolov5 format
os.makedirs('/content/data/labels/valid/', exist_ok=True)
os.makedirs('/content/data/images/valid/', exist_ok=True)

# Define current image folder
tmp_images_path = '/content/val_images/hands_val/'
# Out:
# rm: cannot remove '/content/data/labels/valid': No such file or directory
# rm: cannot remove '/content/data/images/valid': No such file or directory

# %%
# Define correct image folders
images_val_path = '/content/data/images/valid/'
labels_val_path = '/content/data/labels/valid/'

# Move images to correct directory
for filename in os.listdir(tmp_images_path):
  scr = os.path.join(tmp_images_path, filename)
  dst = os.path.join(images_val_path, filename)
  shutil.move(src=scr, dst=dst)

# %%
df = pd.read_csv('/content/drive/MyDrive/pose_estimation/val.csv')
df.head()
# Out:
#          image_name  ...                                     hand_keypoints
# 0  000000425226.jpg  ...  [308.0, 239.0, 0.1408521831035614, 321.0, 226....
# 1  000000458992.jpg  ...  [391.0, 311.0, 0.017855476588010788, 372.5, 33...
# 2  000000458992.jpg  ...  [10.0, 323.0, 0.09969476610422134, 22.0, 355.0...
# 3  000000031817.jpg  ...  [252.0, 182.0, 0.011041253805160522, 238.5, 18...
# 4  000000182611.jpg  ...  [271.0, 243.0, 0.08970954269170761, 286.0, 246...
#
# [5 rows x 3 columns]

# %%
data_numpy = df.to_numpy()
data_numpy.shape
# Out:
# (1051, 3)

# %%
# Get bbox information
images_names_val = data_numpy[:,0]
bboxes_val = get_info(data_numpy[:,1])

images_names_val = np.array(images_names_val)
bboxes_val = np.array(bboxes_val)

# %%
# Create text files for yolov5 training
unique_filenames, filenames_counts = np.unique(images_names_val, return_counts=True)
print(len(unique_filenames))
prepare_yolo_data(unique_filenames, bboxes_val, images_names_val, images_val_path, labels_val_path)
# Out:
# 609

# %% [markdown]
# ## Trian

# %%
# !unzip -q /content/drive/MyDrive/pose_estimation/hands_train.zip -d '/content/train_images/'

# %%
# !rm -r '/content/data/labels/train'
# !rm -r '/content/data/images/train'
# Make directioris like yolov5 format
os.makedirs('/content/data/labels/train/', exist_ok=True)
os.makedirs('/content/data/images/train/', exist_ok=True)

# Define current image folder
tmp_images_path = '/content/train_images/hands_train/'
# Out:
# rm: cannot remove '/content/data/labels/train': No such file or directory
# rm: cannot remove '/content/data/images/train': No such file or directory

# %%
# Define correct image folders
images_train_path = '/content/data/images/train/'
labels_train_path = '/content/data/labels/train/'

# Move images to correct directory
for filename in os.listdir(tmp_images_path):
  scr = os.path.join(tmp_images_path, filename)
  dst = os.path.join(images_train_path, filename)
  shutil.move(src=scr, dst=dst)

# %%
df = pd.read_csv('/content/drive/MyDrive/pose_estimation/train.csv')
df.head()
# Out:
#          image_name  ...                                     hand_keypoints
# 0  000000184659.jpg  ...  [477.0, 138.0, 0.2964617609977722, 464.0, 123....
# 1  000000184659.jpg  ...  [453.0, 69.0, 0.1306665688753128, 431.5, 89.0,...
# 2  000000457254.jpg  ...  [297.0, 344.0, 0.07652954012155533, 317.0, 340...
# 3  000000064909.jpg  ...  [289.0, 442.0, 0.05950009822845459, 277.5, 451...
# 4  000000064909.jpg  ...  [214.0, 344.0, 0.13771122694015503, 231.5, 333...
#
# [5 rows x 3 columns]

# %%
data_numpy = df.to_numpy()
data_numpy.shape
# Out:
# (27700, 3)

# %%
# Get bbox information
images_names_train = data_numpy[:,0]
bboxes_train = get_info(data_numpy[:,1])

images_names_train = np.array(images_names_train)
bboxes_train = np.array(bboxes_train)

# %%
# Create text files for yolov5 training
unique_filenames, filenames_counts = np.unique(images_names_train, return_counts=True)
print(len(unique_filenames))
prepare_yolo_data(unique_filenames, bboxes_train, images_names_train, images_train_path, labels_train_path)
# Out:
# 16107

# %% [markdown]
# # Set model configuration
#
# More complex discription [here](https://models.roboflow.com/object-detection/yolov5)

# %%
yaml_file = "train: //content/data/images/train\nval: //content/data/images/valid\n\nnc: 1\nnames: ['hand']"

with open("//content/data.yaml", "w") as f:
  f.write(yaml_file)

# %%
# Define number of classes based on YAML
import yaml
with open("/content/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
# Configuration file
# %cat /content/yolov5/models/yolov5l.yaml
# Out:
# # parameters
# nc: 80  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, C3, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# Change model parameters
# %%writetemplate /content/custom_yolov5x.yaml

# parameters
nc: {num_classes}  # number of classes
depth_multiple: 1.0  # model depth multiple
width_multiple: 1.0  # layer channel multiple

# anchors
anchors:
  - [10,13, 16,30, 33,23]  # P3/8
  - [30,61, 62,45, 59,119]  # P4/16
  - [116,90, 156,198, 373,326]  # P5/32

# YOLOv5 backbone
backbone:
  # [from, number, module, args]
  [[-1, 1, Focus, [64, 3]],  # 0-P1/2
   [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
   [-1, 3, C3, [128]],
   [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
   [-1, 9, C3, [256]],
   [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
   [-1, 9, C3, [512]],
   [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
   [-1, 1, SPP, [1024, [5, 9, 13]]],
   [-1, 3, C3, [1024, False]],  # 9
  ]

# YOLOv5 head
head:
  [[-1, 1, Conv, [512, 1, 1]],
   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
   [[-1, 6], 1, Concat, [1]],  # cat backbone P4
   [-1, 3, C3, [512, False]],  # 13

   [-1, 1, Conv, [256, 1, 1]],
   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
   [[-1, 4], 1, Concat, [1]],  # cat backbone P3
   [-1, 3, C3, [256, False]],  # 17 (P3/8-small)

   [-1, 1, Conv, [256, 3, 2]],
   [[-1, 14], 1, Concat, [1]],  # cat head P4
   [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)

   [-1, 1, Conv, [512, 3, 2]],
   [[-1, 10], 1, Concat, [1]],  # cat head P5
   [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)

   [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
  ]

# %% [markdown]
# # Training
#
# Some arguments for training:
#
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights.
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# !python '/content/yolov5/train.py' --img 416 --batch 16 --epochs 200 --data '/content/data.yaml' --cfg /content/custom_yolov5x.yaml --weights /content/yolov5/content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results2/weights/last.pt --project /content/drive/MyDrive/pose_estimation/yolov5 --name yolov5x_results  --cache
# Out:
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 12 (delta 6), reused 7 (delta 4), pack-reused 0
# Unpacking objects: 100% (12/12), done.
# From https://github.com/ultralytics/yolov5
#    86897e3..6b634c6  master      -> origin/master
#    24ee803..629b69a  C5_breakout -> origin/C5_breakout
#  * [new branch]      C6          -> origin/C6
# github: ⚠️ WARNING: code is out of date by 2 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 v4.0-66-g86897e3 torch 1.7.0+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='/content/custom_yolov5x.yaml', data='/content/data.yaml', device='', epochs=200, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='yolov5x_results', noautoanchor=False, nosave=False, notest=False, project='/content/drive/MyDrive/pose_estimation/yolov5', quad=False, rect=False, resume=False, save_dir='/content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results', single_cls=False, sync_bn=False, total_batch_size=16, weights='/content/yolov5/content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results2/weights/last.pt', workers=8, world_size=1)
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Start Tensorboard with "tensorboard --logdir /content/drive/MyDrive/pose_estimation/yolov5", view at http://localhost:6006/
# 2021-02-06 20:51:41.384178: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Focus                     [3, 64, 3]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  1   1611264  models.common.C3                        [256, 256, 9]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  1   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  1   2624512  models.common.SPP                       [1024, 1024, [5, 9, 13]]
#   9                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     32310  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model Summary: 499 layers, 46631350 parameters, 46631350 gradients, 114.2 GFLOPS
#
# Transferred 648/650 items from /content/yolov5/content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results2/weights/last.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 110 .bias, 110 conv.weight, 107 other
# train: Scanning '//content/data/labels/train.cache' for images and labels... 16107 found, 0 missing, 0 empty, 6 corrupted: 100% 16107/16107 [00:00<00:00, 127708231.62it/s]
# train: Caching images (6.1GB): 100% 16101/16101 [00:53<00:00, 299.91it/s]
# val: Scanning '//content/data/labels/valid.cache' for images and labels... 609 found, 0 missing, 0 empty, 0 corrupted: 100% 609/609 [00:00<00:00, 141396.69it/s]
# val: Caching images (0.2GB): 100% 609/609 [00:02<00:00, 218.08it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 6.08, Best Possible Recall (BPR) = 1.0000
# Image sizes 416 train, 416 test
# Using 4 dataloader workers
# Logging results to /content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results
# Starting training for 200 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     11/199      4.4G   0.03086   0.01458         0   0.04544        11       416: 100% 1007/1007 [06:37<00:00,  2.53it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:12<00:00,  1.54it/s]
#                  all         609    1.05e+03       0.809       0.821       0.844       0.578
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     12
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 v4.0-69-ga5359f6 torch 1.7.0+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='/content/custom_yolov5x.yaml', data='/content/data.yaml', device='', epochs=200, evolve=False, exist_ok=True, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], linear_lr=False, local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='yolov5x_results', noautoanchor=False, nosave=False, notest=False, project='/content/drive/MyDrive/pose_estimation/yolov5', quad=False, rect=False, resume=False, save_dir='/content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results', single_cls=False, sync_bn=False, total_batch_size=16, weights='/content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results/weights/last.pt', workers=8, world_size=1)
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Start Tensorboard with "tensorboard --logdir /content/drive/MyDrive/pose_estimation/yolov5", view at http://localhost:6006/
# 2021-02-07 21:37:40.956536: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Focus                     [3, 64, 3]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  1   1611264  models.common.C3                        [256, 256, 9]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  1   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  1   2624512  models.common.SPP                       [1024, 1024, [5, 9, 13]]
#   9                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     32310  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model Summary: 499 layers, 46631350 parameters, 46631350 gradients, 114.2 GFLOPS
#
# Transferred 648/650 items from /content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results/weights/last.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 110 .bias, 110 conv.weight, 107 other
# train: Scanning '//content/data/labels/train' for images and labels... 4592 found, 0 missing, 0 empty, 0 corrupted:  29% 4592/16107 [00:01<00:03, 3272.95it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000177356.jpg: labels require 5 columns each
# train: Scanning '//content/data/labels/train' for images and labels... 4937 found, 0 missing, 0 empty, 1 corrupted:  31% 4937/16107 [00:01<00:03, 3321.84it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000188606.jpg: non-normalized or out of bounds coordinate labels
# train: Scanning '//content/data/labels/train' for images and labels... 6630 found, 0 missing, 0 empty, 2 corrupted:  41% 6630/16107 [00:02<00:02, 3330.58it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000240568.jpg: labels require 5 columns each
# train: Scanning '//content/data/labels/train' for images and labels... 10033 found, 0 missing, 0 empty, 3 corrupted:  62% 10033/16107 [00:03<00:01, 3346.37it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000364188.jpg: labels require 5 columns each
# train: Scanning '//content/data/labels/train' for images and labels... 15115 found, 0 missing, 0 empty, 4 corrupted:  94% 15115/16107 [00:04<00:00, 3274.97it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000548702.jpg: labels require 5 columns each
# train: Scanning '//content/data/labels/train' for images and labels... 15778 found, 0 missing, 0 empty, 5 corrupted:  98% 15778/16107 [00:04<00:00, 3247.93it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000570680.jpg: labels require 5 columns each
# train: Scanning '//content/data/labels/train' for images and labels... 16107 found, 0 missing, 0 empty, 6 corrupted: 100% 16107/16107 [00:04<00:00, 3317.48it/s]
# train: New cache created: //content/data/labels/train.cache
# train: Scanning '//content/data/labels/train.cache' for images and labels... 16107 found, 0 missing, 0 empty, 6 corrupted: 100% 16107/16107 [00:00<00:00, 138154712.74it/s]
# train: Caching images (6.1GB): 100% 16101/16101 [00:51<00:00, 313.91it/s]
# val: Scanning '//content/data/labels/valid' for images and labels... 609 found, 0 missing, 0 empty, 0 corrupted: 100% 609/609 [00:00<00:00, 1227.86it/s]
# val: New cache created: //content/data/labels/valid.cache
# val: Scanning '//content/data/labels/valid.cache' for images and labels... 609 found, 0 missing, 0 empty, 0 corrupted: 100% 609/609 [00:00<00:00, 6499570.32it/s]
# val: Caching images (0.2GB): 100% 609/609 [00:02<00:00, 241.25it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 6.08, Best Possible Recall (BPR) = 1.0000
# Image sizes 416 train, 416 test
# Using 4 dataloader workers
# Logging results to /content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results
# Starting training for 200 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     64/199     4.41G   0.02381   0.01132         0   0.03512        11       416: 100% 1007/1007 [06:16<00:00,  2.67it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:11<00:00,  1.69it/s]
#                  all         609    1.05e+03        0.83       0.877        0.89       0.647
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     65/199     4.42G   0.02465   0.01181         0   0.03646        12       416: 100% 1007/1007 [06:13<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.67it/s]
#                  all         609    1.05e+03       0.824       0.885        0.89       0.647
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     66/199     4.42G   0.02492   0.01193         0   0.03685        12       416: 100% 1007/1007 [06:14<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.69it/s]
#                  all         609    1.05e+03       0.812         0.9       0.891       0.648
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     67/199     4.43G   0.02484   0.01186         0    0.0367         9       416: 100% 1007/1007 [06:13<00:00,  2.70it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.68it/s]
#                  all         609    1.05e+03       0.827       0.884       0.891       0.648
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     68/199     4.43G   0.02475   0.01193         0   0.03668        14       416: 100% 1007/1007 [06:14<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.69it/s]
#                  all         609    1.05e+03       0.826       0.884       0.891       0.648
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     69/199     4.43G   0.02484     0.012         0   0.03685        14       416: 100% 1007/1007 [06:13<00:00,  2.70it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.69it/s]
#                  all         609    1.05e+03       0.825       0.886       0.891       0.648
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     70/199     4.43G   0.02471   0.01192         0   0.03663        13       416: 100% 1007/1007 [06:12<00:00,  2.70it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.74it/s]
#                  all         609    1.05e+03       0.826       0.885        0.89       0.648
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     71/199     4.43G   0.02467   0.01197         0   0.03663        13       416: 100% 1007/1007 [06:10<00:00,  2.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.74it/s]
#                  all         609    1.05e+03       0.822       0.891       0.891       0.648
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     72
0.648
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     99/199     4.43G   0.02322   0.01112         0   0.03434        19       416: 100% 1007/1007 [06:10<00:00,  2.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.72it/s]
#                  all         609    1.05e+03       0.849       0.867       0.888       0.648
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    100/199     4.43G   0.02306     0.011         0   0.03406        19       416: 100% 1007/1007 [06:11<00:00,  2.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.74it/s]
#                  all         609    1.05e+03       0.849       0.867       0.887       0.648
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    101/199     4.43G   0.02306   0.01106         0   0.03412        15       416: 100% 1007/1007 [06:11<00:00,  2.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.69it/s]
#                  all         609    1.05e+03        0.85       0.866       0.887       0.648
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    102/199     4.43G   0.02295   0.01103         0   0.03398        13       416: 100% 1007/1007 [06:10<00:00,  2.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.73it/s]
#                  all         609    1.05e+03       0.835       0.881       0.887       0.647
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    103/199     4.43G   0.02285   0.01088         0   0.03373         5       416: 100% 1007/1007 [06:10<00:00,  2.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.74it/s]
#                  all         609    1.05e+03       0.836       0.881       0.887       0.647
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    104/199     4.43G   0.02291   0.01082         0   0.03373        11       416: 100% 1007/1007 [06:11<00:00,  2.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.74it/s]
#                  all         609    1.05e+03       0.835       0.881       0.887       0.647
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    105/199     4.43G   0.02268   0.01088         0   0.03355        10       416: 100% 1007/1007 [06:10<00:00,  2.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.74it/s]
#                  all         609    1.05e+03       0.834       0.882       0.886       0.647
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    106/199     4.43G   0.02259   0.01082         0   0.03341         9       416: 100% 1007/1007 [06:11<00:00,  2.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.78it/s]
#                  all         609    1.05e+03       0.835       0.882       0.886       0.647
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    107/199     4.43G   0.02261   0.01078         0   0.03339        16       416: 100% 1007/1007 [06:09<00:00,  2.73it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.78it/s]
#                  all         609    1.05e+03       0.837       0.881       0.886       0.646
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    108/199     4.43G   0.02246   0.01067         0   0.03314         7       416: 100% 1007/1007 [06:10<00:00,  2.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.74it/s]
#                  all         609    1.05e+03       0.838       0.881       0.887       0.646
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    109/199     4.43G   0.02242   0.01062         0   0.03304        46       416:  98% 988/1007 [06:03<00:06,  2.75it/s]

# %%
# !python '/content/yolov5/train.py' --img 416 --batch 16 --epochs 200 --data '/content/data.yaml' --cfg /content/custom_yolov5x.yaml --weights /content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results/weights/last.pt --project /content/drive/MyDrive/pose_estimation/yolov5 --name yolov5x_results  --cache --exist
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 v4.0-69-ga5359f6 torch 1.7.0+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='/content/custom_yolov5x.yaml', data='/content/data.yaml', device='', epochs=200, evolve=False, exist_ok=True, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], linear_lr=False, local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='yolov5x_results', noautoanchor=False, nosave=False, notest=False, project='/content/drive/MyDrive/pose_estimation/yolov5', quad=False, rect=False, resume=False, save_dir='/content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results', single_cls=False, sync_bn=False, total_batch_size=16, weights='/content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results/weights/last.pt', workers=8, world_size=1)
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Start Tensorboard with "tensorboard --logdir /content/drive/MyDrive/pose_estimation/yolov5", view at http://localhost:6006/
# 2021-02-08 08:51:06.548678: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Focus                     [3, 64, 3]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  1   1611264  models.common.C3                        [256, 256, 9]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  1   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  1   2624512  models.common.SPP                       [1024, 1024, [5, 9, 13]]
#   9                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     32310  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model Summary: 499 layers, 46631350 parameters, 46631350 gradients, 114.2 GFLOPS
#
# Transferred 648/650 items from /content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results/weights/last.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 110 .bias, 110 conv.weight, 107 other
# train: Scanning '//content/data/labels/train' for images and labels... 4709 found, 0 missing, 0 empty, 0 corrupted:  29% 4709/16107 [00:01<00:03, 3174.22it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000177356.jpg: labels require 5 columns each
# train: Scanning '//content/data/labels/train' for images and labels... 5031 found, 0 missing, 0 empty, 1 corrupted:  31% 5031/16107 [00:01<00:03, 3185.75it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000188606.jpg: non-normalized or out of bounds coordinate labels
# train: Scanning '//content/data/labels/train' for images and labels... 6349 found, 0 missing, 0 empty, 2 corrupted:  39% 6349/16107 [00:02<00:03, 3241.69it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000240568.jpg: labels require 5 columns each
# train: Scanning '//content/data/labels/train' for images and labels... 10085 found, 0 missing, 0 empty, 3 corrupted:  63% 10085/16107 [00:03<00:01, 3139.40it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000364188.jpg: labels require 5 columns each
# train: Scanning '//content/data/labels/train' for images and labels... 15005 found, 0 missing, 0 empty, 4 corrupted:  93% 15005/16107 [00:04<00:00, 3297.29it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000548702.jpg: labels require 5 columns each
# train: Scanning '//content/data/labels/train' for images and labels... 15681 found, 0 missing, 0 empty, 5 corrupted:  97% 15681/16107 [00:04<00:00, 3328.86it/s]train: WARNING: Ignoring corrupted image and/or label //content/data/images/train/000000570680.jpg: labels require 5 columns each
# train: Scanning '//content/data/labels/train' for images and labels... 16107 found, 0 missing, 0 empty, 6 corrupted: 100% 16107/16107 [00:05<00:00, 3221.06it/s]
# train: New cache created: //content/data/labels/train.cache
# train: Scanning '//content/data/labels/train.cache' for images and labels... 16107 found, 0 missing, 0 empty, 6 corrupted: 100% 16107/16107 [00:00<00:00, 188708532.20it/s]
# train: Caching images (6.1GB): 100% 16101/16101 [00:49<00:00, 326.27it/s]
# val: Scanning '//content/data/labels/valid' for images and labels... 609 found, 0 missing, 0 empty, 0 corrupted: 100% 609/609 [00:00<00:00, 1294.25it/s]
# val: New cache created: //content/data/labels/valid.cache
# val: Scanning '//content/data/labels/valid.cache' for images and labels... 609 found, 0 missing, 0 empty, 0 corrupted: 100% 609/609 [00:00<00:00, 5400277.24it/s]
# val: Caching images (0.2GB): 100% 609/609 [00:02<00:00, 253.94it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 6.08, Best Possible Recall (BPR) = 1.0000
# Image sizes 416 train, 416 test
# Using 4 dataloader workers
# Logging results to /content/drive/MyDrive/pose_estimation/yolov5/yolov5x_results
# Starting training for 200 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    110/199     4.41G   0.02046  0.009548         0   0.03001        11       416: 100% 1007/1007 [06:16<00:00,  2.67it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:11<00:00,  1.68it/s]
#                  all         609    1.05e+03       0.839        0.88       0.887       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    111/199     4.42G   0.02088   0.00979         0   0.03067        12       416: 100% 1007/1007 [06:13<00:00,  2.70it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.59it/s]
#                  all         609    1.05e+03       0.838       0.879       0.887       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    112/199     4.42G   0.02128  0.009959         0   0.03124        12       416: 100% 1007/1007 [06:13<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.66it/s]
#                  all         609    1.05e+03       0.838       0.879       0.887       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    113/199     4.42G   0.02137   0.01006         0   0.03143         9       416: 100% 1007/1007 [06:13<00:00,  2.70it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.71it/s]
#                  all         609    1.05e+03       0.838       0.879       0.887       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    114/199     4.42G   0.02128   0.01005         0   0.03133        14       416: 100% 1007/1007 [06:13<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.59it/s]
#                  all         609    1.05e+03       0.837       0.879       0.887       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    115/199     4.43G   0.02154   0.01027         0   0.03181        14       416: 100% 1007/1007 [06:14<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.58it/s]
#                  all         609    1.05e+03       0.823       0.895       0.887       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    116/199     4.43G   0.02142   0.01017         0   0.03158        13       416: 100% 1007/1007 [06:14<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.70it/s]
#                  all         609    1.05e+03       0.839       0.877       0.887       0.646
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    117/199     4.43G    0.0215    0.0103         0    0.0318        13       416: 100% 1007/1007 [06:14<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.58it/s]
#                  all         609    1.05e+03       0.839       0.877       0.887       0.646
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    118/199     4.43G   0.02148   0.01016         0   0.03164        13       416: 100% 1007/1007 [06:13<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.53it/s]
#                  all         609    1.05e+03       0.824       0.895       0.886       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    119/199     4.43G   0.02133   0.01017         0   0.03149        20       416: 100% 1007/1007 [06:13<00:00,  2.70it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.63it/s]
#                  all         609    1.05e+03       0.822       0.896       0.887       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    120/199     4.43G   0.02144   0.01029         0   0.03172        13       416: 100% 1007/1007 [06:13<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.69it/s]
#                  all         609    1.05e+03       0.835       0.883       0.886       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    121/199     4.43G   0.02164    0.0102         0   0.03183        12       416: 100% 1007/1007 [06:12<00:00,  2.70it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.62it/s]
#                  all         609    1.05e+03       0.825       0.894       0.886       0.644
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    122/199     4.43G   0.02146    0.0103         0   0.03176        17       416: 100% 1007/1007 [06:13<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.49it/s]
#                  all         609    1.05e+03       0.829        0.89       0.886       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    123/199     4.43G   0.02139   0.01025         0   0.03165        12       416: 100% 1007/1007 [06:13<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.66it/s]
#                  all         609    1.05e+03       0.832       0.888       0.886       0.644
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    124/199     4.43G   0.02132   0.01018         0    0.0315        12       416: 100% 1007/1007 [06:14<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.55it/s]
#                  all         609    1.05e+03       0.831       0.888       0.886       0.644
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    125/199     4.43G   0.02144   0.01013         0   0.03158        13       416: 100% 1007/1007 [06:14<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.61it/s]
#                  all         609    1.05e+03       0.833       0.885       0.886       0.644
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    126/199     4.43G   0.02116  0.009996         0   0.03116        11       416: 100% 1007/1007 [06:14<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.64it/s]
#                  all         609    1.05e+03       0.833       0.886       0.886       0.644
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    127/199     4.43G   0.02121   0.01003         0   0.03123        10       416: 100% 1007/1007 [06:14<00:00,  2.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [00:05<00:00,  3.68it/s]
#                  all         609    1.05e+03       0.832       0.886       0.885       0.643
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#